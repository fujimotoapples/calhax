# %%
import requests
import datetime
import time
import json
import pandas as pd
import numpy as np

# %%
with open('weather.json',"r") as w:
    weather_dictionary=json.load(w)
weather_dictionary['data']
# Out:
# {'sunlightTimes': [{'midnight': 1665817200,
#    'midnightUTCOffset': -7,
#    'dawn': 1665841829,
#    'dawnUTCOffset': -7,
#    'sunrise': 1665843397,
#    'sunriseUTCOffset': -7,
#    'sunset': 1665883972,
#    'sunsetUTCOffset': -7,
#    'dusk': 1665885540,
#    'duskUTCOffset': -7},
#   {'midnight': 1665903600,
#    'midnightUTCOffset': -7,
#    'dawn': 1665928283,
#    'dawnUTCOffset': -7,
#    'sunrise': 1665929853,
#    'sunriseUTCOffset': -7,
#    'sunset': 1665970291,
#    'sunsetUTCOffset': -7,
#    'dusk': 1665971861,
#    'duskUTCOffset': -7},
#   {'midnight': 1665990000,
#    'midnightUTCOffset': -7,
#    'dawn': 1666014736,
#    'dawnUTCOffset': -7,
#    'sunrise': 1666016308,
#    'sunriseUTCOffset': -7,
#    'sunset': 1666056611,
#    'sunsetUTCOffset': -7,
#    'dusk': 1666058183,
#    'duskUTCOffset': -7},
#   {'midnight': 1666076400,
#    'midnightUTCOffset': -7,
#    'dawn': 1666101190,
#    'dawnUTCOffset': -7,
#    'sunrise': 1666102764,
# ...

# %%
def weathermaker(dictionary):
    tide=pd.DataFrame.from_dict(dictionary,orient='columns').drop(columns='utc')
